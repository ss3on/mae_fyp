# %%
import re
from pathlib import Path
from markdown import markdown
from collections import defaultdict
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from sentence_transformers import SentenceTransformer, util, models

from src.file_handling import file_location

data = file_location.FolderPathOfASME()
data_path = data.data
md_path = data.asme_jmd / 'markdown'


model_id = "microsoft/Phi-4-mini-instruct"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="auto")
llm = pipeline("text-generation", model=model, tokenizer=tokenizer)

def prompt_keywords(text: str, top_n: int = 20):
    prompt = f"""
Extract the top {top_n} technical keywords or keyphrases from the following scientific text.
Focus on domain-specific concepts, methods, equations, and recurring themes in mechanical or systems design.
Avoid generic terms and prioritize phrases that reflect unique contributions, techniques, or models.
Return the output as a numbered list, sorted by relevance.

Text:
{text}
"""
    response = llm(prompt, max_new_tokens=200, temperature=0.3)[0]["generated_text"]
    return response
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Some parameters are on the meta device because they were offloaded to the cpu.
# Device set to use cuda:0

# %%
def markdown_to_text(md_content: str) -> str:
    html = markdown(md_content)
    text = re.sub(r"<[^>]+>", " ", html)
    return re.sub(r"\s+", " ", text).strip()


def parse_keywords(raw_output: str):
    lines = raw_output.split("\n")
    keywords = []
    for line in lines:
        match = re.match(r"\d+\.\s*(.+)", line)
        if match:
            kw = match.group(1).lower().strip()
            kw = re.sub(r"[^\w\s\-]", "", kw)
            keywords.append(kw)
    return keywords

# %% [markdown]
# ### vram exceeds 32GB

# %%
results = {}
test_size = 10
n = 0
for md_path in md_path.glob("*.md"):
    text = markdown_to_text(md_path.read_text(encoding="utf-8"))
    raw_output = prompt_keywords(text)
    keywords = parse_keywords(raw_output)
    results[md_path.stem] = keywords
    n += 1
    if n == test_size:
        break

# %% [markdown]
# ### chunk and llm

# %%
def chunk_markdown(text: str, min_length=300):
    sections = re.split(r"\n#{1,3}\s+", text)
    return [s.strip() for s in sections if len(s.strip()) > min_length]

word_embedding_model = models.Transformer("globuslabs/ScholarBERT-XL")
pooling_model = models.Pooling(word_embedding_model.get_word_embedding_dimension(), pooling_mode="mean")
embedder = SentenceTransformer(modules=[word_embedding_model, pooling_model])
# Out:
# Some weights of BertModel were not initialized from the model checkpoint at globuslabs/ScholarBERT-XL and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def process_markdown(md_path, top_n=10):
    text = markdown_to_text(md_path.read_text(encoding="utf-8"))
    chunks = chunk_markdown(text)
    all_keywords = []

    for chunk in chunks:
        raw = prompt_keywords(chunk, top_n=top_n)
        keywords = parse_keywords(raw)
        all_keywords.extend(keywords)

    return all_keywords

# %% [markdown]
# ### Over 10 minutes and not done

# %%
test_results = {}
for test_md in list(md_path.glob('*.md'))[:5]:
    process_markdown(test_md)
    test_results[test_md.stem] = process_markdown(test_md)
print(test_results)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 3
#       1 test_results = {}
#       2 for test_md in list(md_path.glob('*.md'))[:10]:
# ----> 3     process_markdown(test_md)
#       4     test_results[test_md.stem] = process_markdown(test_md)
#       5 print(test_results)
#
# Cell In[25], line 7, in process_markdown(md_path, top_n)
#       4 all_keywords = []
#       6 for chunk in chunks:
# ----> 7     raw = prompt_keywords(chunk, top_n=top_n)
#       8     keywords = parse_keywords(raw)
#       9     all_keywords.extend(keywords)
#
# Cell In[16], line 30, in prompt_keywords(text, top_n)
#      20 def prompt_keywords(text: str, top_n: int = 20):
#      21     prompt = f"""
#      22 Extract the top {top_n} technical keywords or keyphrases from the following scientific text.
#      23 Focus on domain-specific concepts, methods, equations, and recurring themes in mechanical or systems design.
#    (...)     28 {text}
#      29 """
# ---> 30     response = llm(prompt, max_new_tokens=200, temperature=0.3)[0]["generated_text"]
#      31     return response
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\pipelines\text_generation.py:332, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     330             else:
#     331                 return super().__call__(list(chats), **kwargs)
# --> 332 return super().__call__(text_inputs, **kwargs)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\pipelines\base.py:1467, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1459     return next(
#    1460         iter(
#    1461             self.get_iterator(
#    (...)   1464         )
#    1465     )
#    1466 else:
# -> 1467     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\pipelines\base.py:1474, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1472 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1473     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1474     model_outputs = self.forward(model_inputs, **forward_params)
#    1475     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1476     return outputs
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\pipelines\base.py:1374, in Pipeline.forward(self, model_inputs, **forward_params)
#    1372     with inference_context():
#    1373         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1374         model_outputs = self._forward(model_inputs, **forward_params)
#    1375         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1376 else:
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\pipelines\text_generation.py:432, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     429 if "generation_config" not in generate_kwargs:
#     430     generate_kwargs["generation_config"] = self.generation_config
# --> 432 output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     434 if isinstance(output, ModelOutput):
#     435     generated_sequence = output.sequences
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\torch\utils\_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\generation\utils.py:2539, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2528     return GenerationMixin.generate(
#    2529         self,
#    2530         inputs,
#    (...)   2534         **kwargs,
#    2535     )
#    2537 elif generation_mode in (GenerationMode.SAMPLE, GenerationMode.GREEDY_SEARCH):
#    2538     # 11. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2539     result = self._sample(
#    2540         input_ids,
#    2541         logits_processor=prepared_logits_processor,
#    2542         stopping_criteria=prepared_stopping_criteria,
#    2543         generation_config=generation_config,
#    2544         synced_gpus=synced_gpus,
#    2545         streamer=streamer,
#    2546         **model_kwargs,
#    2547     )
#    2549 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2550     # 11. run beam sample
#    2551     result = self._beam_search(
#    2552         input_ids,
#    2553         logits_processor=prepared_logits_processor,
#    (...)   2557         **model_kwargs,
#    2558     )
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\generation\utils.py:2870, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2868     is_prefill = False
#    2869 else:
# -> 2870     outputs = model_forward(**model_inputs, return_dict=True)
#    2872 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    2873 model_kwargs = self._update_model_kwargs_for_generation(
#    2874     outputs,
#    2875     model_kwargs,
#    2876     is_encoder_decoder=self.config.is_encoder_decoder,
#    2877 )
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\accelerate\hooks.py:175, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     173         output = module._old_forward(*args, **kwargs)
#     174 else:
# --> 175     output = module._old_forward(*args, **kwargs)
#     176 return module._hf_hook.post_forward(module, output)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\utils\generic.py:940, in can_return_tuple.<locals>.wrapper(self, *args, **kwargs)
#     938 if return_dict_passed is not None:
#     939     return_dict = return_dict_passed
# --> 940 output = func(self, *args, **kwargs)
#     941 if not return_dict and not isinstance(output, tuple):
#     942     output = output.to_tuple()
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\models\phi3\modeling_phi3.py:465, in Phi3ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     433 @can_return_tuple
#     434 @auto_docstring
#     435 def forward(
#    (...)    446     **kwargs: Unpack[TransformersKwargs],
#     447 ) -> CausalLMOutputWithPast:
#     448     r"""
#     449     Example:
#     450
#    (...)    463     "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     464     ```"""
# --> 465     outputs: BaseModelOutputWithPast = self.model(
#     466         input_ids=input_ids,
#     467         attention_mask=attention_mask,
#     468         position_ids=position_ids,
#     469         past_key_values=past_key_values,
#     470         inputs_embeds=inputs_embeds,
#     471         use_cache=use_cache,
#     472         cache_position=cache_position,
#     473         **kwargs,
#     474     )
#     476     hidden_states = outputs.last_hidden_state
#     477     # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\utils\generic.py:1064, in check_model_inputs.<locals>.wrapper(self, *args, **kwargs)
#    1061                 module.forward = make_capture_wrapper(module, original_forward, key, specs.index)
#    1062                 monkey_patched_layers.append((module, original_forward))
# -> 1064 outputs = func(self, *args, **kwargs)
#    1065 # Restore original forward methods
#    1066 for module, original_forward in monkey_patched_layers:
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\models\phi3\modeling_phi3.py:401, in Phi3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, cache_position, **kwargs)
#     398 position_embeddings = self.rotary_emb(hidden_states, position_ids)
#     400 for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 401     hidden_states = decoder_layer(
#     402         hidden_states,
#     403         attention_mask=causal_mask,
#     404         position_ids=position_ids,
#     405         past_key_values=past_key_values,
#     406         use_cache=use_cache,
#     407         cache_position=cache_position,
#     408         position_embeddings=position_embeddings,
#     409         **kwargs,
#     410     )
#     411 hidden_states = self.norm(hidden_states)
#     412 return BaseModelOutputWithPast(
#     413     last_hidden_state=hidden_states,
#     414     past_key_values=past_key_values if use_cache else None,
#     415 )
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\modeling_layers.py:94, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      91         logger.warning_once(message)
#      93     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 94 return super().__call__(*args, **kwargs)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\accelerate\hooks.py:175, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     173         output = module._old_forward(*args, **kwargs)
#     174 else:
# --> 175     output = module._old_forward(*args, **kwargs)
#     176 return module._hf_hook.post_forward(module, output)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\models\phi3\modeling_phi3.py:263, in Phi3DecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, cache_position, position_embeddings, **kwargs)
#     260 residual = hidden_states
#     261 hidden_states = self.input_layernorm(hidden_states)
# --> 263 hidden_states, self_attn_weights = self.self_attn(
#     264     hidden_states=hidden_states,
#     265     attention_mask=attention_mask,
#     266     position_ids=position_ids,
#     267     past_key_values=past_key_values,
#     268     use_cache=use_cache,
#     269     cache_position=cache_position,
#     270     position_embeddings=position_embeddings,
#     271     **kwargs,
#     272 )
#     273 hidden_states = residual + self.resid_attn_dropout(hidden_states)  # main diff with Llama
#     275 residual = hidden_states
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\accelerate\hooks.py:175, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     173         output = module._old_forward(*args, **kwargs)
#     174 else:
# --> 175     output = module._old_forward(*args, **kwargs)
#     176 return module._hf_hook.post_forward(module, output)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\utils\deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\transformers\models\phi3\modeling_phi3.py:176, in Phi3Attention.forward(self, hidden_states, position_embeddings, attention_mask, past_key_values, cache_position, **kwargs)
#     173 input_shape = hidden_states.shape[:-1]
#     174 hidden_shape = (*input_shape, -1, self.head_dim)
# --> 176 qkv = self.qkv_proj(hidden_states)
#     177 query_pos = self.config.num_attention_heads * self.head_dim
#     178 query_states = qkv[..., :query_pos]
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\torch\nn\modules\module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\torch\nn\modules\module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\accelerate\hooks.py:170, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     169 def new_forward(module, *args, **kwargs):
# --> 170     args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     171     if module._hf_hook.no_grad:
#     172         with torch.no_grad():
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\accelerate\hooks.py:360, in AlignDevicesHook.pre_forward(self, module, *args, **kwargs)
#     352         if (
#     353             value is not None
#     354             and self.tied_params_map is not None
#     355             and value.data_ptr() in self.tied_params_map
#     356             and self.execution_device not in self.tied_params_map[value.data_ptr()]
#     357         ):
#     358             self.tied_pointers_to_remove.add((value.data_ptr(), self.execution_device))
# --> 360         set_module_tensor_to_device(
#     361             module,
#     362             name,
#     363             self.execution_device,
#     364             value=value,
#     365             fp16_statistics=fp16_statistics,
#     366             tied_params_map=self.tied_params_map,
#     367         )
#     369 return send_to_device(args, self.execution_device), send_to_device(
#     370     kwargs, self.execution_device, skip_keys=self.skip_keys
#     371 )
#
# File E:\dev\mae_fyp\.venv\Lib\site-packages\accelerate\utils\modeling.py:343, in set_module_tensor_to_device(module, tensor_name, device, value, dtype, fp16_statistics, tied_params_map, non_blocking, clear_cache)
#     341             module._parameters[tensor_name] = param_cls(new_value, requires_grad=old_value.requires_grad)
#     342 elif isinstance(value, torch.Tensor):
# --> 343     new_value = value.to(device, non_blocking=non_blocking)
#     344 else:
#     345     new_value = torch.tensor(value, device=device)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 12s for 10 markdowns
# ### Works, remove noise from md

# %%
from src.file_handling import file_location
folder_path = file_location.FolderPathOfASME()
md_path = folder_path.asme_jmd / 'markdown'


from keybert import KeyBERT

model_name = "allenai/specter2_base"
kw_model = KeyBERT(model=model_name)


test_mds = list(md_path.glob("*.md"))[:10]
test_results = {}

for md in test_mds:
    with open(md, "r", encoding="utf-8") as f:
        doc = f.read()
    keywords = kw_model.extract_keywords(
        doc,
        keyphrase_ngram_range=(1, 3),
        stop_words="english",
        top_n=30
    )
    test_results[md.stem] = keywords

print(test_results)
# Out:
# No sentence-transformers model found with name allenai/specter2_base. Creating a new one with mean pooling.
# {'doi_10.1115_1.1286084': [('workspace boundary point', 0.7851), ('manipulator accessibility boundary', 0.7746), ('points wrist workspaces', 0.7746), ('manipulator workspaces workspaces', 0.7745), ('workspace plane boundary', 0.7741), ('manipulator workspace boundary', 0.7719), ('workspace boundary constraint', 0.7718), ('workspace contains points', 0.7711), ('workspace boundary surface', 0.7707), ('workspace boundary constraints', 0.7686), ('manipulator contains points', 0.7681), ('workspaces different manipulators', 0.7663), ('intersection region wrist', 0.766), ('coordinates point surface', 0.766), ('sections workspace boundary', 0.7654), ('reachable workspace surface', 0.7654), ('region wrist boundary', 0.7648), ('manipulator workspace asme', 0.7646), ('boundary points wrist', 0.7646), ('sphere intersecting wrist', 0.7645), ('point centerline', 0.7644), ('workspace boundary general', 0.7643), ('robot trajectories point', 0.7641), ('dexterity respect trajectory', 0.7641), ('intersecting wrist workspace', 0.7637), ('problems using manipulator', 0.7636), ('workspace boundary problems', 0.7635), ('geometric optimization manipulator', 0.7634), ('wrist workspace boundary', 0.7634), ('workspaces planes respectively', 0.7633)], 'doi_10.1115_1.1286124': [('gearsets grinding edge', 0.8098), ('design gears using', 0.8087), ('cutting bevel gears', 0.8069), ('bevel gear grinding', 0.8048), ('modifications bevel gears', 0.8034), ('gear grinding ease', 0.7979), ('reduce gear noise', 0.7979), ('crowning applied gearset', 0.7973), ('reduction bevel gear', 0.7955), ('bevel gears using', 0.7953), ('gear geometry reduces', 0.7951), ('design gears', 0.7943), ('gear geometry optimizations', 0.794), ('bevel gears mech', 0.7907), ('gear roll position', 0.7905), ('bevel gears', 0.7905), ('reduce gear', 0.7904), ('bevel gears zero', 0.7903), ('gears tapered tooth', 0.7897), ('crowning generated tilting', 0.7895), ('gear design tapered', 0.7894), ('rolling gearset idea', 0.788), ('gear requirement gearset', 0.7877), ('pinion gear cutting', 0.7862), ('outline gear tooth', 0.7861), ('pinion gear roll', 0.7858), ('tilting face cutter', 0.7856), ('bevel gears auto', 0.7854), ('keywords bevel gears', 0.7846), ('gear cutting shown', 0.7845)], 'doi_10.1115_1.1286188': [('element analysis crimping', 0.7836), ('element model crimping', 0.7814), ('crimping process simulation', 0.7806), ('simulate crimping process', 0.7802), ('piston crimping process', 0.779), ('crimping process piston', 0.776), ('fea model piston', 0.7758), ('crimping process analyzed', 0.7748), ('crimping process result', 0.7716), ('crimping process method', 0.7711), ('optimizing crimping process', 0.771), ('piston components crimping', 0.7702), ('piston slipper crimping', 0.7689), ('crimping process s1050', 0.7673), ('crimping process used', 0.7671), ('plastic deformation analysis', 0.7666), ('loading crimping process', 0.7666), ('stresses crimping process', 0.7666), ('material crimping process', 0.7665), ('slipper piston crimping', 0.7662), ('crimping process results', 0.7657), ('crimping process design', 0.7653), ('stress crimping process', 0.765), ('used simulate crimping', 0.7646), ('die geometry crimping', 0.7641), ('designing crimping process', 0.7641), ('ansys piston slipper', 0.7634), ('slipper crimping process', 0.7632), ('crimping process simplified', 0.7624), ('analysis crimping process', 0.7624)], 'doi_10.1115_1.1286189': [('gears asme eng', 0.8168), ('gears asme', 0.813), ('gear vibrations asme', 0.8088), ('parameter modeling gears', 0.8053), ('properties planetary gears', 0.8052), ('international gearing conference', 0.8042), ('transmission gearing conference', 0.803), ('epicyclic gears asme', 0.8022), ('gears fundamental dynamics', 0.8017), ('gear dynamic response', 0.8008), ('planetary gears fundamental', 0.7998), ('introduction planetary gears', 0.7994), ('gear dynamic models', 0.7992), ('gear response 18', 0.798), ('modeling gears', 0.798), ('asme eng ind', 0.7978), ('gear ...

# %%
from src.file_handling import file_location
folder_path = file_location.FolderPathOfASME()
md_path = folder_path.asme_jmd / 'markdown'


from keybert import KeyBERT

model_name = "allenai/specter2_base"
kw_model = KeyBERT(model=model_name)


model_name = "allenai/specter2_base"
kw_model = KeyBERT(model=model_name)

# %%
def remove_html_comments(text):
    return re.sub(r"<!--.*?-->", "", text)

def strip_markdown_syntax(text):
    text = re.sub(r"\[.*?\]\(.*?\)", "", text)
    text = re.sub(r"!\[.*?\]\(.*?\)", "", text)
    text = re.sub(r"`{1,3}.*?`{1,3}", "", text)
    text = re.sub(r"^```[\s\S]*?```", "", text, flags=re.MULTILINE)
    text = re.sub(r"[#*>_~\-]{2,}", "", text)
    return text

def normalize_whitespace(text):
    text = re.sub(r"\s+", " ", text)
    text = re.sub(r"\.{3,}", ".", text)
    text = re.sub(r"[^\w\s.,;:()\-]", "", text)
    return text.strip()

def extract_core_sections(text):
    start = re.search(r"^\s*##\s*\d*\s*(abstract|introduction)", text, re.IGNORECASE | re.MULTILINE)
    end = re.search(r"^\s*##\s*\d*\s*(references?|bibliography|acknowledgments?|funding|appendix|supplementary|conflict of interests?|authors? contributions)", text, re.IGNORECASE | re.MULTILINE)
    if start and end:
        return text[start.start():end.start()]
    elif start:
        return text[start.start():]
    elif end:
        return text[:end.start()]
    else:
        return text

def md_noise_reduction(raw_text):
    text = remove_html_comments(raw_text)
    text = extract_core_sections(text)
    text = strip_markdown_syntax(text)
    text = normalize_whitespace(text)
    return text

# %%
test_mds = list(md_path.glob("*.md"))[:10]
test_results = {}

for md in test_mds:
    with open(md, "r", encoding="utf-8") as f:
        doc = f.read()
    print(md.stem)
    print(md_noise_reduction(doc))
    print()
# Out:
# doi_10.1115_1.1286084
# 1 Introduction The goal of this investigation is to determine the exact point accessibility of robotic manipulators. This information is useful for engineers to optimally posit robot cells and to adequately plan robot trajectories. The point accessibility of a robot to an operating point is defined as the set of all directions from there the point is accessible by the robots end-effector. This set of directions, as the accessibility regions, constructed on the service sphere of the point. The service sphere  1,2  of an operating point is the sphere centered at the point with the radius the length of the robots hand size. wrist design encountered limits of joint rotation. Yang et al.  8  introduced a method of disassembling the manipulator into the regional and wrist structures for determining if a point is accessible from a particular direction. Emiris and Tourassis  17  and Basavaraj and Duffy  18  derived measures which indicate the percentage of directions from which a point can be accessed. Recently, Abdel-Malek  2  worked on the optimal locality problem of manipulator arms. In the approach, initial boundary points of the wrist workspaces are first found as seeds based on the method introduced by Huag et al.  9  . In turn, a numerical perturbation technique is used to trace out the boundaries of the entire wrist workspace. However, in the paper, no examples with the exact shape of the accessibility regions have been provided. Besides, the practical issue of having possible rotational limits on wrist joints has not been considered. In this paper, we take a geometric approach that is different from existing ones. As a result, we believe, for the first time, the exact point accessibility regions of a 6-DOF manipulator imposed with practical joint limits are revealed. Our method of determining accessibility involves deriving constraint equations, which define curves on the surface of the service sphere. Accessibility boundaries will arise from both the regional structure and the wrist structure. The uniqueness of the solution of the constraint equations is guaranteed by a reasonable assumption that the regional structure is much larger than the wrist structure. In this case, the relatively small service sphere will have only one intersection region with the wrist boundary. Roth  3  determined that the reachable workspace of a general manipulator was bounded by the surface of a generalized torus. Gupta and Roth  4  extended this approach by considering n degree-of-freedom manipulators. Kumar and Waldron  5  introduced the concept of dexterous workspace. The dexterous workspace was determined to be contained within the wrist workspace, reduced in size by the length of the end effector. This subject was further studied by Vijay et al.  6  , Lai and Menq  7  , and Yang et al.  8  . Later Huag et al.  9  and Yang and Huag  10  analytically formulated the manipulator workspace boundary problems by using the manipulator kinematic constraint equations and their Jacobian matrices. Examples were provided for planar Stewart platform and planar 4-bar manipulators. Based on this concept, Yeh and Abdel-Malek  11  obtained the analytical workspace boundary for general 3-DOF mechanisms. of The ability to solve the constraint equations and to plot the accessibility boundary curves depends on the adequate selection of the coordinate systems. A designated coordinate system is defined for the derivation of each constraint equations. This coordinate system is referred to as the neutral coordinate system. The importance of the selection of neutral coordinate systems is to ensure a rapid reach of unambiguous solutions during the numerical process. These neutral coordinate frames can be easily selected as described in the next section. 2 Description of the Method The concept of dexterous versus reachable workspace indicates that not all reachable points can be accessed from every direction, but does not provide information about the accessibility of  ...
#
# doi_10.1115_1.1286124
# Hermann J. Stadtfeld Vice President Research and Development Uwe Gaiser Manager Application Engineering The Gleason Works, 1000 University Avenue, P.O. Box 22970, Rochester, New York 14692-2970 e-mail: www.gleason.com The Ultimate Motion Graph The innovation was to develop a gear geometry that reduces or eliminates gear noise and increases the strength of gears. Gear noise is a common problem in all bevel and hypoid gear drives. A variety of expensive gear geometry optimizations are applied daily in all hypoid gear manufacturing plants, to reduce gear noise. In many cases those efforts have little success. Additional expensive finishing operations (lapping after the grinding) ar applied to achieve the goal of quiet and stong gear sets. The ultimate motion graph is a concept for modulating the tooth surfaces that uses a physical effect to cancel out the dynamic disturbances that are naturally generated by all up-to-date known kind of gears. The ultimate motion graph also eliminates the sensitivity of gears against deflection under load or displacements because of manufacturing tolerances. Lower dynamic disturbances will also increase the dynamic strength.  S1050-0472  00  00203-8  Keywords: Bevel Gears, Hypoid Gears, Motion Graph, Noise Reduction, Bevel Gear Grinding, Ease-off, Adjustability Design Practice Today According to classic design, gearsets have three principal types of tooth contact pattern. The type of tooth contact depends to the highest degree on the possible flank form modifications versus the conjugate flank form. can cross many contact lines as shown in Fig. 1, or it might be identical to one contact line. It can  but does not have to  be identical to the path of contact  see also  2  . The second element to generate crowning is a profile modification on the tool. A concave curvature on the cutting edge of a blade  versus a straight edge  will take stock off on top and flank and cause a circular profile crowning. Figure 2 presents a profile crowning that results in a high bias contact if it is the only or the dominating correction. The third element of flank crowning is a flank twist from toe to heel. Figure 3 shows the classic flank twist. The most commonly used methods to obtain an Ease-Off as shown in Fig. 3 is a cutter tilt around the root angle axis and a corresponding change of the machine root angle. Other methods are the use of modified roll and helical motion  1  . All real bevel and hypoid gear application used in power transmissions  and many cylindrical gears  use a combination of all three types of crowning. The intent of flank modifications is to provide a limited contact area under no load or light load which provides insensitivity to gear housing tolerances, inaccuracies in the gear members and assembly, as well as deflections. The corrections keep the contact pattern inside the boundaries of the teeth and, therefore, prevent edge contact. For cutting bevel gears there are three mechanisms to create modifications that have the intent to locate the bearing contact. Those modifications are called crowning. In case of face milling, there is no basic machine set-up that provides conjugate flank geometry. Cutting in the root line plane and rolling in a plane that matches the pitch line can only be approximated for gears with a tapered tooth depth. The elements of flank form correction are used in the gear design of tapered depth tooth systems to eliminate the systematic deviations from conjugate to some extent and leave a desired crowning characteristic. Principally, this leads to similar flank corrections that were once applied to face hobbed gearsets with a uniform tooth depth design. The first element is lengthwise crowning which is a circular modification along the face width. If a ring gear is cut to the conjugate theory and a circular modification is applied to the pinion the result of the interaction between pinion and gear after cutting is shown in Fig. 1. Length crowning can be generated by  ...
#
# doi_10.1115_1.1286188
# 1 Introduction Axial-piston swash-plate type hydrostatic pumps and motors are widely used in hydraulic transmissions. Hydraulic transmissions have a unique ability to transmit very large amounts of power using a compact system. die  involved in this process. Due to the complexity of the parts geometry and the shape change during the process, analyzing individual parts separately is infeasible. The area of large deformation plasticity and contact problems has been researched for cold forging and extrusion. Pillinger, Hartley, Sturgess, and Rowe  1  studied an elastic-plastic 3-D FEM using a simple test part and verified the results experimentally. The incremental techniques used in the study were based on the Prandtl-Reuss flow rule and von Mises yield criterion. Thirukkonda, Sirnivasan, and Weiss  2  discussed the plastic instability and flow localization during compressive deformation of a flow softening material using FE simulation. The strains at which the material became unstable were determined depending on the strain-rate sensitivity of the material. Machining defects, mechanical damage, and friction were found to have some effect on the plastic instability of the materials through the development of deformation inhomogeneities. The slipper-piston component, presented in Fig. 1, is an integral component of a hydraulic pump. The piston in Fig. 1 is loosely connected to the slipper to allow the ball head of the piston to move freely in the socket of the slipper. A crimping process is usually used for connecting the slipper and piston components. In the crimping process, a brass slipper socket is crimped onto a steel piston ball using a two-piece die as shown in Fig. 2. During the crimping process, the brass slipper will undergo large plastic deformations to embrace the piston ball. Residual stresses will therefore exist in the material after the crimping process is finished. Liou and Jiang  3  focused their research on stress distributions, especially residual stress distributions, of the forging process. The FEM was used in a study to identify a set of controlling process parameters which can be used for examining the residual stress distribution in forged products. While the previous studies gave good understanding of the processes that were focused on, these methods cannot be applied directly to the analysis of the crimping process. The goal of this study is to create a technique that can be used to analyze the slipper-piston crimping process in both the male-piston and maleslipper design. The results can then be used to optimize this pro- Another design configuration for the piston-slipper component is shown in Fig. 3. In this design, the ball head is part of the slipper. During the connecting process, the piston is deformed to embrace the ball-head of the slipper. The advantage of this design is in moving the forces between the piston and slipper away from the bottom of the slipper. This will significantly increase the stability of the piston in the pump or motor. However, the material used in the piston is steel and unlike brass, which is usually used in the slipper component, steel will have larger stresses during the crimping process. The design shown in Fig. 1 will be referred to as the malepiston model, and the design shown in Fig. 3 will be referred to as the male-slipper model in this study. This paper reports on the application of the Finite Element Method  FEM  to the analysis of the stresses and deformations in the piston-slipper component during and after the crimping process. In order to obtain accurate analysis results, the FEM used has to be able to solve large strain plasticity problems. Large deformation of the slipper makes the linear assumption unsuitable for this analysis. In addition, there are three objects  slipper, piston, and Contributed by the Reliability, Stress Analysis and Failure Prevention Committee for publication in the J OURNAL OF M ECHANICAL D ESIGN . Manuscript received Sept. 1999. A ...
#
# doi_10.1115_1.1286189
# 1 Introduction Planetary gears yield several advantages over conventional parallel shaft gear systems. They produce high speed reductions in compact spaces, greater load sharing, higher torque to weight ratio, diminished bearing loads and reduced noise and vibration. They are used in automobiles, helicopters, aircraft engines, heavy machinery, and a variety of other applications. Despite their advantages, the noise induced by the vibration of planetary gear systems remains a key concern. In helicopters, for example, cabin noise exceeding 100 dB is directly traceable to the last stage planetary gear mounted to the cabin. published. In fact, comprehensive planetary gear dynamic response analyses are notably lacking in the literature. While the present work is still subject to a number of modeling idealizations, the modeling has higher fidelity representation of the dynamic excitations and tooth contact mechanics than published models. In this regard, the presented results provide a benchmark for further development of planetary gear dynamic models. preciselysemiThe literature on planetary gear mechanics emphasizes highly idealized lumped parameter modeling wherein the gears are rigid bodies interconnected by springs representing meshing teeth and support bearings. For free vibration analyses, see  1-6  . Kahraman  7,8  used two- and three-dimensional models to examine the dynamic response of both time-invariant and time-varying representations. Velex and Flamand  9  used lumped modeling  10  and a Ritz approach to examine the dynamic response induced by mesh parametric excitations. In all these studies, the gear bodies are represented using lumped parameter models. Valco  11  used a non-linear finite element model of a planetary gear system to calculate stresses, strains and deformations in the gear bodies under static loading; dynamic response is not considered. Gradu et al.  12  used a finite element model to obtain the dynamic response of various planetary gear systems with different planet spacings. The dynamic excitation, which is typically not wellknown, must be specified externally in that model. 2 Finite Element GLYPHlt;213gt; Contact Mechanics Model Planetary gears have received considerably less research attention than single mesh gear pairs. There is a particular scarcity of dynamic response calculations. The purpose of this work is to characterize the dynamic response of a planetary gear system under a wide range of operating conditions. The analytical technique combines a unique, semi-analytical finite element approach with detailed contact modeling at the tooth mesh. This approach was specifically developed to examine the mechanics of machined, contacting elastic bodies such as gears. The analytical finite element formulation does not require a highly refined mesh at the contacting tooth surfaces. This dramatically reduces the computational effort and allows calculation of the dynamic response at a sufficient number of time steps to study the response in the frequency domain. In contrast, the need for extremely refined gear tooth meshes limits conventional finite element analysis to static analyses and free vibration eigensolutions. The current analysis provides a more accurate and comprehensive study of planetary gear dynamic response than is reasonably possible, or has been conducted, with conventional finite element analysis. Experimental measurement of planetary gear dynamic response under operating conditions is difficult due to the limited access and multiple moving bodies. As a result, few benchmark experimental results suitable for dynamic model validation have been 1 Corresponding author. Contributed by the Power Transmission amp; Gearing Committee for publication in the J OURNAL OF M ECHANICAL D ESIGN . Manuscript received May 1999. Associate Technical Editor: R. F. Handschuh. The sun gear speed is specified and the nominal rigid body motions of the components are determined according to basic planetary g ...
#
# doi_10.1115_1.1286236
# 1 Introduction When considering hypoid gears, it is generally assumed that they mesh with a point contact. Crossed helical gears of the same skew clearly mesh with point contact. However, crossed helical gears can be cut using the teeth of one as the cutter of the other, as in worm gears. In this case, it cannot simply be assumed that crossed helical gears mesh with a point contact. It is possible that spatial gearing causes them to mesh with a line contact-or close to it. On the other hand, the current requirement for meshing is only that the scalar product of the common normal vector that draws the contact point on the tooth surfaces and the relative velocity vector of tooth surfaces equals zero. However, this condition is not the necessary and sufficient condition under which a pair of tooth surfaces mesh with a line contact. reaches point P 8 . The vector of relative velocity between tooth surfaces at point P 8 is represented by w 8 . In addition, point P 8 moves arc length ds 2 in the direction of w 8 and reaches the next point P 9 at time t 2 5 t 1 1 dt after time dt , and both tooth surfaces make contact along contact line x ( s , t 2). The vector of relative velocity between tooth surfaces at point P 9 is represented by w 9 . Then curve PP 8 P amp; 9 will be drawn on tooth surface x 2 . This is shown in curve x 2( s 2). Next, it is assumed that mean point P is moved to point P 1 on curve x ( s , t 0). At this point, points P 1, P 1 8 , and P 1 9 are obtained as well as points P, P 8 , and P 9 . When these points are connected, curve K 1( s 2) is obtained. Curve K 1( s 2) is called the slide line which passes through point P 1 and crosses the contact line. The slide line which passes origin P is specifically defined as tooth trace x 2( s 2). The tooth trace will exist innumerably if mean point P is innumerably taken on the contact line x ( s , t 0). A similar definition can be applied to tooth surface x 1 . The tooth trace on tooth surface x 1 is defined as x 1( s 1). Recent researches on hypoid gears and spiral bevel gears are proposed over various areas. For example, there are researches on gear geometry  1-9  , gear operation  10,11  and misalignment  12  . This study clarifies the new conditions besides the condition described above that are necessary so that a pair of gears may mesh with line contact. Equations from differential show us that tooth surfaces of hypoid gears mesh with line contact in the neighborhood of the pitch point. Thus, the elements of two tooth surfaces that have a line contact are determined by differential geometry. 2 Contact Line and Tooth Trace on Tooth Surface When a pair of gears meshes with a line contact, the line moves on the conjugate tooth surfaces with each rotation of the gears. Figure 1 shows where one tooth surface x 2 is fixed and the other tooth surface x 1 slips and rolls on tooth surface x 2 when the two gears mesh. Tooth surfaces x 1 and x 2 make contact along a curve x ( s , t 0) at a certain time t 0 . Then, the two surfaces come into contact along a new curve x ( s , t ) at time t after a very short time dt . In each point on the first curve x ( s , t 0), relative velocities occur between the two surfaces. Similarly, a relative velocity also occurs at each point on curve x ( s , t ). Mean point, P is decided on the curve x ( s , t 0 ) and we let it be origin P. The vector of relative velocity between conjugate tooth surfaces passing through origin P is represented by w . When time t 1 after time dt is expressed as t 1 5 t 0 1 dt , the contact line which passes origin P moves on tooth surface x 2 and reaches the next contact line x ( s , t 1). At this point, point P on tooth surface x 2 moves to point P 8 on line x ( s , t 1). That is, point P moves an arc length ds 2 in the direction of w and geometry The contact line between tooth surfaces x 1 and x 2 moves through space with time t and draws one locus surface x ( s , t ). Moreover, the surfaces of the revolution obtaine ...
#
# doi_10.1115_1.1286870
# 1 Introduction Typical mechanical wrists consist of a serial chain of three successively orthogonal and mutually intersecting rotations. See Tsai  1  for a discussion of these, including geared forms. The first two axes form a pointing system which is a universal joint  u-joint  . This u-joint is a two degree-of-freedom  dof  subsystem of the three dof wrist. The function of this subsystem is to point the third wrist axis, called the roll axis. Kinematic singularities of three-axis wrists occur when the roll axis lies in the plane of the two u-joint axes, Paul and Stevenson  2  . Singularities of the wrist are a consequence of the singularities brought by the u-joint pointing subsystem within the wrist. 2.1 Notation and Coordinate Frame Assignments. Analysis uses Denavit-Hartenberg  DH  parameters and frame assignments as in Craig  12  . Coordinate frame i ( X ˆ i , Y ˆ i , Z ˆ i ) is attached to link i ( i 5 0,1, . . . ,7). For i 5 0, i 2 1 5 7 and for i 5 7, i 1 1 5 0. BodyFrame 0 ( X ˆ 0 , Y ˆ 0 , Z ˆ 0 ) is fixed. Figure 1 shows the frame assignments, except that all origins should be coincident at O .  Note shown for sake of image clarity.  All a i 2 1 5 90 deg  the links are symmetric  . In the configuration shown in Fig. 1, the joint angles have the values u 1 5 u 3 5 u 5 5 u 7 5 90 deg, and u 2 5 u 6 5 180 deg, and u 4 5 u 0 52 90 deg. The linkage is intentionally shown in this symmetric pose. Dextrous wrists have been developed with double u-joints for the pointing subsystems Susnjara and Fleck  3  , Milenkovic  4-6  , Trevelyan  7  , Rosheim  8  . The systems are all actuated symmetrically, usually through gearing. The centers of the u-joints are offset. Six dof manipulators which use such double centered  non-spherical  wrists generally have coupled positional and orientational kinematics, Piepier  9  . Double u-joint wrists are capable of producing orientations without singularities as standalone systems. When used as the wrist in a six dof manipulator, their coupled kinematics has shown coupled wristarm singularities, Williams  10  . Stanis ˇ ic  and Duta  11  describe a mechanical equivalent to these which can be constructed with a single center. In this paper a new type of spherical and singularity-free point05 1 Currently a design engineer with Lockheed Martin Space Systems Company, Missiles and Space Operations. Contributed by the Mechanisms Committee for publication in the J OURNAL OF M ECHANICAL D ESIGN . Manuscript received Dec. 1998. Associate Technical Editor: V. Kumar Fig. 1 The orthogonal spherical eight-bar linkage Adjacent frames have their relative orientation related by (3 3 3) direction cosine matrices deduced from the (4 3 4) homogeneous transformation  12  . 2.2 Forward Kinematic Pointing Equations. Closure of the linkage in Fig. 1 requires, Closure Eq.  3  is partitioned into equivalent right and left half loops, for i 5 0, . . . ,7. With all a i 2 1 5 90 deg, i i 2 1 R reduces to, where, The right half loop 4 0 R R and left half loop 4 0 R L are expanded from Eqs.  2  , and  5  , where si 5 sin u i and ci 5 cos u i . The direction cosine matrices relate the eight joint angles to the direction cosines of the 0 Z ˆ 4 axis. The direction of 0 Z ˆ 4  the systems pointing output  is expressed in terms of the joint angles by the third columns of Eqs.  6  and  7  . Eqs.  6  and  7  must satisfy Eq.  4  to maintain closure. Introducing equal pairs of joint rotations, and u 5 5 u 7 (9) reduces the eight-bar linkage from five dof to three dof and Eqs.  6  and  7  reduce to Thus, as a result of the orthogonal links and the equal rotations imposed in Eqs.  8  and  9  , The equal rotations in Eqs.  8  and  9  result in a condition where joint angles u 0 and u 4 also become equal. Referring to Appendix 1, from the  1,1  and  2,2  elements of Eqs.  10  and  11  , and likewise from the  1,2  and  2,1  elements, Define a plane of the equator which contains the Z ˆ 2 and Z ˆ 6 axes. Symmetric links and Eqs.  8   ...
#
# doi_10.1115_1.1287498
# 1 Introduction Finding global solutions to a nonlinear optimization problem is a difficult task still not resolved to a satisfactory level by the general theory of optimization. The problem is difficult due to the fact that, in general, the behavior of the objective throughout the space is unknown. The existing nonlinear gramming methods are based on exploiting the local properties of the objective function and converging to a solution that in many cases is only a local minimum. However, several local minima may exist at which the corresponding function values may differ substantially. Most of the time we can only find the functions local characteristics which is the reason for many well developed local optimization methods  1,2  . Only in some cases where the behavior of the function is known, i.e., convex, quadratic function, the chance of finding the global optima is greatly enhanced. Situations where practical results may be achieved are described in Wilde  3  . function prowill be introduced with the assistance of computer graphics which is one reason for recent popularity of this theory. Throughout the paper the analyticity of the functions  satisfaction of CauchyRiemann equations  will be emphasized since this is the main reason for obtaining some important results about iterations. Presumably, readers will be familiar with complex numbers as building blocks of analytic functions. The chaotic descent method and all the reasoning used to develop it will be presented. The theoretical discussion will be supported with numerical experiments. However, before proceeding further, we would like to emphasize that no method today can guarantee finding global minima for the reasons described above; therefore, the method described here is not an exception. One can be assured in success only if the exhaustive search in the whole feasible domain is performed. The exhaustive search is usually unacceptable for obvious reasons, but here is where the method is aiming to bring an improvement. The procedure attempts to perform the exhaustive search in an efficient manner therefore changing a priori negative connotation of exhaustive. 2 Iteration of Complex Analytic Functions interval clustering As a first step, it is necessary to define the notion of iteration of a complex analytic function f ( z ) where z is a complex number. The iteration is a repeated application of function f on a complex variable z . Specifically, if we select a point z 0 in the complex plane C and apply f repeatedly on z 0 , we are constructing, in turn, the points z 0 , z 1 5 f ( z 0), z 2 5 f ( z 1 ) . . . . In this fashion iteration can be viewed simply as a feedback process for which behavior depends on the operator f . When this operator is linear, it is quite easy to predict the outcome of the iteration process. However, the situation is quite different when f is a nonlinear operator. In these instances, the outcome of iterations is unpredictable and its study reveals quite intricate properties. The problem of designing algorithms that obtain global solutions is difficult since in general there is no a local criterion for deciding whether a local solution is global. During the past three decades on the subject of global optimization or related problems a variety of deterministic and stochastic methods for finding global solutions have been developed. Deterministic methods include enumerative techniques, cutting planes, branch and bound, decomposition based approaches, bilinear programming, analysis, interior point methods, and approximate algorithms for large-scale problems. Stochastic methods include simulated annealing, pure random search techniques, and the method. Most of these methods, due to the problems intrinsic complexities, are based on iterative numerical techniques that are all tuned up for fastest possible convergence and satisfaction of different criteria. However, it appears that the iteration itself, as a dynamic iterative process, has been negl ...
#
# doi_10.1115_1.1287499
# Introduction This paper presents a new linkage synthesis method which facilitates approximate position specifications. Although pinned linkage mechanisms are durable and easy to build, more expensive systems involving components such as cams, gears, and linear actuators are often the choice of mechanical designers. In many cases, linkage mechanisms can be designed to perform the same tasks as the more complex systems. However, the design process required to create the linkage mechanisms may not be as intuitive. The development of synthesis methodologies which allow exploration of solutions in an intuitively simple format is essential in making linkage synthesis a more practical and cost effective option for designers. New linkage synthesis methods presented in this paper provide a more realistic representation of design problems and present the solution spaces to these problems in a format that can easily be explored and manipulated by the designer. Precision position methods  1  have been successfully implemented in interactive computer software for the design of four-bar and multi-loop linkages  LINCAGES  2  ; KINSYN  3  ; SPHINX  4  ; and LINCAGES-6  5  . However, in many instances, design tasks do not necessitate precise position constraints at all positions. For example, consider a mechanism required to assist a technician in pouring a hot solution from a bottle into a filter as depicted in Fig. 1. This task could be best described by exact first and last positions, PP1 and PP2, and an acceptable region for the intermediate positions. Mathematically, the acceptable region can be represented by allowing tolerances on intermediate precision positions. These positions are then called approximate positions. Approximate position AP1 is used to encourage the mechanism to lift the bottle upwards off the heater, and approximate positions AP2 through AP4 are used to encourage a delay in pouring until the bottle is directly over the filter and also to help avoid interference with the filter walls. twosimple ing the position requirements shown in Fig. 1. Each blackened rectangle indicates that no dyad solution exists for that groundpivot location. The solution space for the second dyad of a four-bar linkage is dependent upon the first dyad. Figure 3 shows a first dyad, W A 1 Z A , chosen from the solution space in Fig. 2 and the corresponding ground-pivot map for the second dyad. The increase in blackened areas indicates that the solution space has been limited by the choice of the first dyad. Through computer implementation, these ground-pivot maps could be explored interactively. The underlying basis of the proposed techniques is precision position synthesis  6  . Most precision-position-based methods that include approximate position constraints also involve some sort of optimization. Sutherland  7  , Gold and Derby  8  , and Ahn  9  added an arbitrary number of approximate positions to the twoand three-precision-position motion generation problem for a four-bar linkage. The approximate positions are specified with precise coordinates. Then, optimization is used to minimize the error at the approximate positions. The search is limited to mechanisms that exactly satisfy the precision positions. The advantage of our proposed method is that a complete solution space is generated which satisfies both the exact and approximate position requirements. Therefore any further optimization can focus on other performance criteria. Downloaded from http:asmedigitalcollection.asme.orgmechanicaldesignarticle-pdf12232785797246278_1.pdf by Massachusetts Inst Of Tech. user on 18 May 2022 APJAPA API Consider the design of a four-bar linkage whose coupler satisfies the position requirements in Fig. 1. This paper will show that the solution space for each dyad of the four-bar can be represented as a ground-pivot map. For each ground pivot in the map either no solutions or a set of solutions exist. For example, Fig. 2 shows a ground-pivot map for the f ...
#
# doi_10.1115_1.1287508
# 1 Introduction 2 Determination of the Bending Strength Geometry Factor AGMA  2  defines the bending strength geometry factor J as Based on the work of Lewis  1  , AGMA  2  has established an improved model for the elastic behavior of gear teeth, which uses the Lewis parabola to determine the critical section by the tangency point of the parabola and the tooth profile. For the cases in which the tangency point is placed on the involute, the J factor can be computed analytically  3  , but usually this point is placed over the root fillet, whose equations are complicated. where every symbol has been described in the nomenclature section. In this equation, - m n and c are given - C c , m N , c r , f nL , f nr and C h  11  can be computed before determining the critical section - tool  K f  12  , sF and hF can be computed from the critical section parameter procedure The problem is to determine the critical section parameter from the condition of tangency of the Lewis parabola and the root trochoid, and numerical techniques with iterative procedures are required. This iterative calculation is what in this work will be replaced by an analytic calculation, which allows computing the J factor without iterations. Mitchiner and Mabie  4  developed a method valid for racktype, standard spur gears, and tables for the AGMA J -factor for usual sets of tooth proportions were given, but neither center distance modifications nor hob offsets nor backlash were considered. Based on the work of Errichello  5-7  , AGMA  2  developed an augmented method considering spur and helical gears, rack-type or pinion-type cutters, tool protuberance, offsets and backlash. This method is general and provides extremely accurate results, but involves an iterative very tedious to implement into a computer program. Also, the iterative nature of the procedure implies that it would be time consuming when used repeatedly, as a part of power transmission optimization  8,9  . 2.1 Parameters Not Depending on the Critical Section. C c , m N , c r , f nr and C h are all independent of the critical section parameter a n . Equations can be found in  2  . From Fig. 1, the load angle f nL is An approximate equation for the J factor has been reported by Carroll and Johnson  10  , but it is only valid for spur gears generated by rack with no backlash, no tool shift and standard center distance. No similar methods have been reported for helical gears. This paper presents an approximate, accurate method for the determination of the critical section parameter, from whose value the J factor can be computed analytically. This method is valid for any set of tool proportions and any values of the tooth numbers, rack shift coefficients, operating center distances, axial contact ratios and helix angles. Moreover, it allows considering the load acting at the tip or at the highest point of single tooth contact  HPSTC  . where rnC is the virtual contact radius and g b the angle between both tooth involutes at the virtual base radius Contributed by the Reliability Stress Analysis amp; Failure Prevention Committee for publication in the J OURNAL OF M ECHANICAL D ESIGN . Manuscript received Aug. 1999. Associate Technical Editor: J. Gao. AGMA computes rnC at the tip or at the HPSTC, depending on the axial contact ratio. Consequently, from Fig. 2, Fig. 2 Load radius at the highest point of single tooth contact Fig. 3 Root fillet generation where subindex 2 denotes the mating gear. Neither rnC nor g b are a function of a n . - 2.2 Parameters Depending on the Critical Section. K f , sF and hF can be only computed from the value of a n . From Fig. 3, where g is the angle between the tooth centerline and the line of centers, and d is the distance between the rolling point and the generating tool tip point, both at the moment in which the critical section is generated. The tooth root is generated at the line of centers, so that the angle g can be expressed as where subindex 0 denotes the tool. Final ...
#
# doi_10.1115_1.1287926
# Suat Genc 1 Plug Power Latham, NY 12110 Robert W. Messler, Jr. 2 Materials Science and Engineering, Rensselaer Polytechnic Institute, Troy, NY 12180 Gary A. Gabriele 2 Mechanical Engineering, Aeronautical Engineering and Mechanics, Rensselaer Polytechnic Institute, Troy, NY 12180 A Method for Attachment Design Concept Development in Integral Snap-fit Assemblies The importance and foundation for attachment-level design of integral snap-fit assemblies was first pointed out by Bonenberger at General Motors 1 -3. Based on that work, a method was developed and tested and is presented here to identify and address important issues at the conceptual stage in a systematic way and generate alternative attachment concepts. The method starts by exploring the design space to generate as many concepts as possible 4. Alternative concepts are generated by considering variations in attachment interface geometry, assembly procedures, actual snap-fit features, and options for fully constraining all parts of the assembly using locators beyond locks. In the last step alternatives are evaluated using a quantitative tool, and a best attachment concept is selected based on design objectives for a particular application. Applying the method to case studies has confirmed that it is a useful design aid for efficiently generating, and evaluating, or simply checking attachment concepts.  S1050-0472  00  01003-5  Keywords: Design Method, Concept Generation or Development, Integral Attachment, Integral Snap-fit Features, Snap-fit Assembly Overview of Integral Attachment Design The use of integral features for attachment assembly is highly recommended to reduce overall product cost by reducing the number of parts and eliminating conventional fasteners  5-7  . Integral attachment features used in plastic part design and manufacture include any and all elements at the interface between parts of an assembly used to enable, assist in, or enhance attachment  8  . These fall into one of three subcategories:  1  elastic,  2  plastic, or  3  rigid features  9  . Integral snap-fit features offer the additional advantages of low insertion force, significant force, no requirement for installation tools, reduced installation time, and built-in indication of quality  i.e., the snap   10  .  1-3  . The geometry of the parts to be attached, applicable installation directions and assembly motions, and numbers, locations, and orientations of integral attachment features on the actively used surfaces or interfaces of the parts being attached were all considered at what Bonenberger called the attachment-level. Genc, et al.  15  grouped these issues into three categories:  1  part interface geometry;  2  assembly procedure; and  3  attachment feature information. Figure 1 shows integral attachment design stages in the overall design process. retention The conceptual design stage consists of two major activities:  1  concept generation; and  2  concept evaluation  12  . Although a number of different concept generation and evaluation techniques have been presented in the literature, each presents only general rules, and none can be easily applied to the integral attachment design problem. Design with integral snap-fit attachment features  one form of integral attachment design  , like all design, can be broadly divided in three principal stages:  1  problem formulation andor design specification;  2  conceptual design; and  3  detail design. In the design specification stage, inputs such as design objectives, constraints, and any other concern  s  are identified, i.e., the problem is defined. Conceptual design or, as it is sometimes called, configuration design  11  , layout design or scheme design or draft  12  , or qualitative synthesis  13  , deals with how parts come together to function in an assembly or structure, what and how features beyond just those for attachment are to be used, their relative positions on the parts, etc. Detail design involves actual sizing of featur ...

# %%
import polars as pl
from pathlib import Path

from src.file_handling.file_location import FolderPathOfASME

folder_path = FolderPathOfASME()
keywords_folder_path = folder_path.asme_jmd / 'keywords'
keybert_bert_folder_path = keywords_folder_path / 'keybert_bert'

dfs :list[pl.DataFrame] = []
for f in keybert_bert_folder_path.glob('*.parquet'):
    df = pl.read_parquet(f)
    dfs.append(df)


dfs_concat = pl.concat(dfs)
dfs_concat
# Out:
# shape: (1_700, 3)
# ┌───────────────────────┬─────────────────────────────────┬────────────────────────────┐
# │ doi                   ┆ keywords                        ┆ scores                     │
# │ ---                   ┆ ---                             ┆ ---                        │
# │ str                   ┆ list[str]                       ┆ list[f64]                  │
# ╞═══════════════════════╪═════════════════════════════════╪════════════════════════════╡
# │ doi_10.1115_1.1286084 ┆ ["joint constraint point", "us… ┆ [0.6197, 0.609, … 0.5832]  │
# │ doi_10.1115_1.1286124 ┆ ["design gears using", "realiz… ┆ [0.693, 0.6909, … 0.6558]  │
# │ doi_10.1115_1.1286188 ┆ ["stress results piston", "pis… ┆ [0.6845, 0.6804, … 0.6489] │
# │ doi_10.1115_1.1286189 ┆ ["dynamic response gears", "mo… ┆ [0.6896, 0.6865, … 0.6509] │
# │ doi_10.1115_1.1286236 ┆ ["point contact line", "surfac… ┆ [0.5836, 0.5833, … 0.5556] │
# │ …                     ┆ …                               ┆ …                          │
# │ doi_10.1115_1.2717233 ┆ ["designs dispensing systems",… ┆ [0.6494, 0.6485, … 0.5949] │
# │ doi_10.1115_1.2717234 ┆ ["parallel manipulator mechani… ┆ [0.6038, 0.6004, … 0.5538] │
# │ doi_10.1115_1.2717323 ┆ ["figures appear poorly", "fli… ┆ [0.6424, 0.6071, … 0.5583] │
# │ doi_10.1115_1.2717611 ┆ ["3t1r parallel manipulators",… ┆ [0.6269, 0.626, … 0.5708]  │
# │ doi_10.1115_1.2722316 ┆ ["generating new knowledge", "… ┆ [0.6181, 0.6047, … 0.5781] │
# └───────────────────────┴─────────────────────────────────┴────────────────────────────┘
