# %% [markdown]
# # Approach 1

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from nltk import ngrams
import os
import string

'''
self-defined pdf2text function: The "parse" funtions needs to be adapted according to specific pdf format of 
a certain jounal
ref source: https://www.reddit.com/r/Python/comments/50r1cs/text_extraction_from_pdf_published_scientific/
'''

def convert_pdf_to_txt_and_metadata(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    metadata=PDFDocument(PDFParser(fp)).info
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()
    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)
    text = retstr.getvalue()
    fp.close()
    device.close()
    retstr.close()
    return text, metadata

def findWord(word, pdftext):
    for sentence in pdftext.split("."):
        if word in sentence:
            print(sentence.replace("\n", " "))
            
def parse(text, content):        
    pages = text.split('\x0c')
    remove_lst = ['', ' ', '  ', '   ']
    pages = [item for item in pages if item not in remove_lst]
    full = []
    ##clean each page
    for page in range(len(pages)):
        if "l\n\nD\no\nw\nn\no\na\nd\ne\nd\n\n" in pages[page]:
            txt1 = pages[page].split('l\n\nD\no\nw\nn\no\na\nd\ne\nd\n\n')[0]
            txt2 = pages[page].split('l\n\nD\no\nw\nn\no\na\nd\ne\nd\n\n')[1].split('\n2\n0\n2\n2')[1]
            txt = (txt1 + txt2)
        else:
            txt = pages[page]
            
        txt = txt.replace('-\n\n', '').split('\n\n')
        txt = [item for item in txt if item not in remove_lst]
        remove = []
        for i in range(len(txt)):
            length = len(txt[i])
            
            ##remove noisy items
            str_len = len(''.join(e for e in txt[i] if e.isalnum() if not e.isdigit()))
            if str_len <= 2 or (str_len < 0.6*length and length < 40):
                remove += [txt[i]]
                continue
                
            ##detect and remove noise (i.e., download links)
            if str_len < 0.6*len(txt[i]):
                txt[i] = txt[i].replace('-\n', '').replace('\n','').strip()
            else:
                txt[i] = txt[i].replace('-\n', '').replace('\n',' ').strip()
            
            ##remove journal logos items
            for item in ['Journal of Mechanical Design',"Transactions of the ASME",'Vol.','Copyright © ',
                         'Contributed','Corresponding author',
                         'Journal of Mechanisms, Transmissions, and Automation in Design']:
                if item in txt[i] and len(txt[i]) < 300:
                    remove += [txt[i]]
                    
            ## remove journal logos contained in text
            for item in ['Journal of Mechanical Design',"Transactions of the ASME",'Vol.','Copyright © ',
                         'Journal of Mechanisms, Transmissions, and Automation in Design']:
                if item in txt[i] and len(txt[i]) >= 300:
                    txt[i] = txt[i].split(item)[0]
                    
            ## remove footnot regaring author info from text
            for item in ['Contributed','Corresponding author']:
                if item in txt[i] and len(txt[i]) >= 300 and len(txt[i].split(item)[1]) < 300:
                    txt[i] = txt[i].split(item)[0]
                    
            ## detect paragraphs that are split into two parts by footnotes
            if i > 0 and i < len(txt) - 1 and len(txt[i]) > 2:
                if txt[i][0:2] in [str(a)+b for a in range(20) for b in list(string.ascii_uppercase)] \
                   and txt[i][-1] == '.':
                    if txt[i-1][-1] not in ['.','?', '!'] and txt[i+1][0] not in list(string.ascii_uppercase):
                        txt[i],txt[i+1] = txt[i+1],txt[i]
 
        ##remove empty items
        remove = set(remove)
        for item in remove:
            txt.remove(item)
        ##insert "@#" between meta data for easy parsing
        if content == 1:
            tmpx = ' '.join(txt)
        else:
            tmpx = ' @# '.join(txt)
        full += [tmpx]
    
    cleaned_text = ' '.join(full)
    return cleaned_text.strip()

# %%
##load the spreadsheet in which the sparsed info will be stored
data = pd.read_excel('jmd_all_updated.xlsx')

##define the dictionary for storing the extracted info
info = {}
info['ref'] = ['']*len(data)
info['ack'] = ['']*len(data)
info['meta'] = ['']*len(data)
info['full_text'] = ['']*len(data)
for no in range(0,len(data)):
    pdf, metadata=convert_pdf_to_txt_and_metadata(os.path.join("folder_with_pdfs", "%d.pdf"%no))
    for i in range(20):
        if i%2 == 1:
            pdf = pdf.replace('(cid:%d)'%i, '(')
        else:
            pdf = pdf.replace('(cid:%d)'%i, ')')
            
    ##split pdf into different sections containing different info and extract the desired info using "parse"
    ref = ''
    for item in ['References\n','References \n','R\ne\nf\ne\nr\ne\nn\nc\ne\ns','Reference\n','Reference \n',
                 'R\ne\nf\ne\nr\ne\nn\nc\ne']:
        if item in pdf:
            ##split on last occurrence
            REF = pdf.rsplit(item,1)[-1] 
            pdf = pdf.rsplit(item,1)[-2]
#             ref = parse(REF,2)
            break
    
    ack = ''
    for item in ['Acknowledgments\n','Acknowledgments \n','A\nc\nk\nn\no\nw\nl\ne\nd\ng\nm\ne\nn\nt\ns',
                 'Acknowledgment\n','Acknowledgment \n','A\nc\nk\nn\no\nw\nl\ne\nd\ng\nm\ne\nn\nt']:
        if item in pdf:
            ##split on last occurrence
            ACK = pdf.rsplit(item,1)[-1]
            pdf = pdf.rsplit(item,1)[-2]
            ack = parse(ACK,1)
            break
    
    meta = ''
    for item in ['DOI: ',"Introduction \n",'Introduction\n','I\nn\nt\nr\no\nd\nu\nc\nt\ni\no\nn\n',
                 'I\nn\nt\nr\no\nd\nu\nc\nt\ni\no\nn \n']:
        if item in pdf:
            ##split on first occurrence
            META = pdf.split(item,1)[0]
            meta = parse(META,2)
            if item == 'DOI: ':
                pdf = pdf.split(item,1)[1][20:]
            else: 
                pdf = 'Introduction\n' + pdf.split(item,1)[-1]
            break
        
    text = parse(pdf,1)
    
    info['ref'][no] = ref
    info['ack'][no] = ack
    info['meta'][no] = meta
    info['full_text'][no] = text

# %%
##capture second-column text in first page going to meta incorretly
n = 0
data = data.astype({"abstract": str})
abstract = list(data['abstract'])
meta1 = ['']*len(data)
for i in range(len(info['meta'])):
# for i in [8]:
    meta = info['meta'][i]
    abst = abstract[i]
    if len(abst) > 10 and abst[-8:]+' @# ' in meta:
        meta1[i] = meta.split(abst[-8:]+' @# ')[-1].replace(' @# ', ' ')
        
##correct main body text by adding 
corrected = ['']*len(data)

for i in range(len(info['full_text'])):
    corrected[i] = meta1[i].strip() + ' ' + info['full_text'][i].strip()

# %%
## The maximal cell length of excel is 32767. Need to cut long text into multiple pieces
body = {}
m = 0
for item in info['full_text']:
    n = int(len(item) / 32767) + 1
    for i in range(n):
        if 'text_' + str(i) not in body.keys():
            body['text_' + str(i)] = ['']*len(data)
        body['text_' + str(i)][m] = item[i*32767:min((i+1)*32767, len(item))]
    m += 1

# %%
data['ref from pdf'] = info['ref']
data['acknowledgment'] = info['ack']
data['main body'] = info['full_text']
data['meta data'] = info['meta']
data['meta to main body'] = meta1
data['correccted main body'] = corrected
for key in body.keys():
    data[key] = body[key]

data.to_excel('jmd_all_updated.xlsx')

# %% [markdown]
# # Approach 2

# %%
'''
Approach 1: not generic, less effective for pdfs of earlier-year papers
Approach 2: generic to all journals, but can't be applied to all pdfs successfully. A little time-consuming 
to install the packages. Run well on Linux (Ubuntu), but not on Windows.
For low-quality pdfs, approach 1 catch paper content more comprehensively, but it's less accurate at the word level.
Many words have extra spaces between letters.
'''

# %%
'''
ref source 1: https://github.com/titipata/scipdf_parser
    pip install git+https://github.com/titipata/scipdf_parser
    ##The following command needs to be run everytime when the script is in use.
    ##The following command needs to run on Linux; the file needs to be revised according to ref 2.
    ##Go to the folder containing the bash file in terminal, then run:
    bash serve_grobid.sh
ref source 2: https://github.com/kermitt2/grobid
'''
import scipdf

# %%
##test
article_dict = scipdf.parse_pdf_to_dict('folder_with_pdfs/131.pdf') # return dictionary
 
## option to parse directly from URL to PDF, if as_list is set to True, output 'text' of parsed section will be in a list of paragraphs instead
# article_dict = scipdf.parse_pdf_to_dict('https://www.biorxiv.org/content/biorxiv/early/2018/11/20/463760.full.pdf', as_list=False)

xml = scipdf.parse_pdf('folder_with_pdfs/131.pdf', soup=True) # option to parse full XML from GROBID

# %%
import pandas as pd
import os

data = pd.read_excel('jmd_all_updated 1.xlsx')

# body = ['']*len(data)
# acknow = ['']*len(data)
path = 'folder_with_pdfs'
for i in range(0,5591):
    text = []
    ack = ''
    try:
        article_dict = scipdf.parse_pdf_to_dict(os.path.join(path,str(i)+'.pdf'))
        for sec in article_dict['sections']:
            head = sec['heading'].replace('\n','').strip()
            if "Acknowledgment" not in head and "acknowledgment" not in head:
                txt = sec['text'].replace('\n','').strip()
                text += [head + ' ' + txt]
            else:
                ack = sec['text'].replace('\n','').strip()
    except:
        print ("Doesn't work for paper " + str(i))
    body_text = ' '.join(text)

    body[i] = body_text
    acknow[i] = ack
# Out:
# /home/curie/anaconda3/envs/parser/lib/python3.9/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# Doesn't work for paper 2467
# Doesn't work for paper 2470
# Doesn't work for paper 2476
# Doesn't work for paper 2478
# Doesn't work for paper 2479
# Doesn't work for paper 2482
# Doesn't work for paper 2492
# Doesn't work for paper 2494
# Doesn't work for paper 2495
# Doesn't work for paper 2496
# Doesn't work for paper 2497
# Doesn't work for paper 2507
# Doesn't work for paper 2508
# Doesn't work for paper 2512
# Doesn't work for paper 2515
# Doesn't work for paper 2516
# Doesn't work for paper 2517
# Doesn't work for paper 2519
# Doesn't work for paper 2521
# Doesn't work for paper 2527
# Doesn't work for paper 2528
# Doesn't work for paper 2531
# Doesn't work for paper 2532
# Doesn't work for paper 2537
# Doesn't work for paper 2541
# Doesn't work for paper 2550
# Doesn't work for paper 2554
# Doesn't work for paper 2556
# Doesn't work for paper 2558
# Doesn't work for paper 2570
# Doesn't work for paper 2575
# Doesn't work for paper 2577
# Doesn't work for paper 2578
# Doesn't work for paper 2579
# Doesn't work for paper 2581
# Doesn't work for paper 2582
# Doesn't work for paper 2594
# Doesn't work for paper 2597
# Doesn't work for paper 2598
# Doesn't work for paper 2605
# Doesn't work for paper 2624
# Doesn't work for paper 2628
# Doesn't work for paper 2630
# Doesn't work for paper 2635
# Doesn't work for paper 2640
# Doesn't work for paper 2644
# Doesn't work for paper 2654
# Doesn't work for paper 2655
# Doesn't work for paper 2658
# Doesn't work for paper 2659
# Doesn't work for paper 2660
# Doesn't work for paper 2662
# Doesn't work for paper 2664
# Doesn't work for paper 2669
# Doesn't work for paper 2671
# Doesn't work for paper 2674
# Doesn't work for paper 2675
# Doesn't work for paper 2676
# Doesn't work for paper 2678
# Doesn't work for paper 2679
# Doesn't work for paper 2680
# Doesn't work for paper 2681
# Doesn't work for paper 2688
# Doesn't work for paper 2693
# Doesn't work for paper 2696
# Doesn't work for paper 2703
# Doesn't work for paper 2709
# Doesn't work for paper 2721
# Doesn't work for paper 2724
# Doesn't work for paper 2733
# Doesn't work for paper 2737
# Doesn't work for paper 2738
# Doesn't work for paper 2741
# Doesn't work for paper 2745
# Doesn't work for paper 2746
# Doesn't work for paper 2748
# Doesn't work for paper 2777
# Doesn't work for paper 2779
# Doesn't work for paper 2780
# Doesn't work for paper 2782
# Doesn't work for paper 2784
# Doesn't work for paper 2785
# Doesn't work for paper 2789
# Doesn't work for paper 2815
# Doesn't work for paper 2831
# Doesn't work for paper 2834
# Doesn't work for paper 2837
# Doesn't work for paper 2846
# Doesn't work for paper 2858
# Doesn't work for paper 2869
# Doesn't work for paper 2873
# Doesn't work for paper 2876
# Doesn't work for paper 2893
# Doesn't work for paper 2900
# Doesn't work for paper 2923
# Doesn't work for paper 2937
# Doesn't work for paper 2945
# Doesn't work for paper 2949
# Doesn't work for paper 2957
# Doesn't work for paper 2963
# Doesn't work for paper 2971
# Doesn't work for paper 2983
# Doesn't work for paper 2986
# Doesn't work for paper 2987
# Doesn't work for paper 2989
# Doesn't work for paper 2990
# Doesn't work for paper 2991
# Doesn't work for paper 2994
# Doesn't work for paper 2996
# Doesn't work for paper 3025
# Doesn't work for paper 3035
# Doesn't work for paper 3046
# Doesn't work for paper 3054
# Doesn't work for paper 3070
# Doesn't work for paper 3078
# Doesn't work for paper 3079
# Doesn't work for paper 3085
# Doesn't work for paper 3094
# Doesn't work for paper 3096
# Doesn't work for paper 3100
# Doesn't work for paper 3108
# Doesn't work for paper 3114
# Doesn't work for paper 3121
# Doesn't work for paper 3129
# Doesn't work for paper 3130
# Doesn't work for paper 3131
# Doesn't work for paper 3133
# Doesn't work for paper 3137
# Doesn't work for paper 3146
# Doesn't work for paper 3159
# Doesn't work for paper 3163
# Doesn't work for paper 3164
# Doesn't work for paper 3175
# Doesn't work for paper 3180
# Doesn't work for paper 3184
# Doesn't work for paper 3185
# Doesn't work for paper 3193
# Doesn't work for paper 3197
# Doesn't work for paper 3199
# Doesn't work for paper 3209
# Doesn't work for paper 3210
# Doesn't work for paper 3214
# Doesn't work for paper 3217
# Doesn't work for paper 3220
# Doesn't work for paper 3224
# Doesn't work for paper 3234
# Doesn't work for paper 3236
# Doesn't work for paper 3239
# Doesn't work for paper 3249
# Doesn't work for paper 3250
# Doesn't work for paper 3254
# Doesn't work for paper 3267
# Doesn't work for paper 3275
# Doesn't work for paper 3283
# Doesn't work for paper 3299
# Doesn't work for paper 3301
# Doesn't work for paper 3306
# Doesn't work for paper 3325
# Doesn't work for paper 3333
# Doesn't work for paper 3346
# Doesn't work for paper 3349
# Doesn't work for paper 3356
# Doesn't work for paper 3365
# Doesn't work for paper 3371
# Doesn't work for paper 3376
# Doesn't work for paper 3380
# Doesn't work for paper 3407
# Doesn't work for paper 3416
# Doesn't work for paper 3421
# Doesn't work for paper 3430
# Doesn't work for paper 3434
# Doesn't work for paper 3441
# Doesn't work for paper 3443
# Doesn't work for paper 3450
# Doesn't work for paper 3452
# Doesn't work for paper 3460
# Doesn't work for paper 3461
# Doesn't work for paper 3473
# Doesn't work for paper 3479
# Doesn't work for paper 3487
# Doesn't work for paper 3489
# Doesn't work for paper 3515
# Doesn't work for paper 3527
# Doesn't work for paper 3530
# Doesn't work for paper 3545
# Doesn't work for paper 3574
# Doesn't work for paper 3580
# Doesn't work for paper 3583
# Doesn't work for paper 3586
# Doesn't work for paper 3624
# Doesn't work for paper 3639
# Doesn't work for paper 3645
# Doesn't work for paper 3649
# Doesn't work for paper 3677
# Doesn't work for paper 3686
# Doesn't work for paper 3697
# Doesn't work for paper 3703
# Doesn't work for paper 3719
# Doesn't work for paper 3764
# Doesn't work for paper 3778
# Doesn't work for paper 3797
# Doesn't work for paper 3801
# Doesn't work for paper 3805
# Doesn't work for paper 3808
# Doesn't work for paper 3811
# Doesn't work for paper 3850
# Doesn't work for paper 3875
# Doesn't work for paper 3882
# Doesn't work for paper 3889
# Doesn't work for paper 3894
# Doesn't work for paper 3900
# Doesn't work for paper 3907
# Doesn't work for paper 3943
# Doesn't work for paper 3951
# Doesn't work for paper 3974
# Doesn't work for paper 3992
# Doesn't work for paper 4001
# Doesn't work for paper 4013
# Doesn't work for paper 4020
# Doesn't work for paper 4027
# Doesn't work for paper 4054
# Doesn't work for paper 4057
# Doesn't work for paper 4062
# Doesn't work for paper 4064
# Doesn't work for paper 4068
# Doesn't work for paper 4070
# Doesn't work for paper 4071
# Doesn't work for paper 4079
# Doesn't work for paper 4092
# Doesn't work for paper 4103
# Doesn't work for paper 4104
# Doesn't work for paper 4111
# Doesn't work for paper 4113
# Doesn't work for paper 4118
# Doesn't work for paper 4119
# Doesn't work for paper 4124
# Doesn't work for paper 4128
# Doesn't work for paper 4129
# Doesn't work for paper 4137
# Doesn't work for paper 4140
# Doesn't work for paper 4141
# Doesn't work for paper 4142
# Doesn't work for paper 4145
# Doesn't work for paper 4150
# Doesn't work for paper 4153
# Doesn't work for paper 4155
# Doesn't work for paper 4168
# Doesn't work for paper 4170
# Doesn't work for paper 4175
# Doesn't work for paper 4185
# Doesn't work for paper 4191
# Doesn't work for paper 4193
# Doesn't work for paper 4195
# Doesn't work for paper 4199
# Doesn't work for paper 4200
# Doesn't work for paper 4206
# Doesn't work for paper 4221
# Doesn't work for paper 4222
# Doesn't work for paper 4226
# Doesn't work for paper 4228
# Doesn't work for paper 4232
# Doesn't work for paper 4238
# Doesn't work for paper 4240
# Doesn't work for paper 4262
# Doesn't work for paper 4271
# Doesn't work for paper 4276
# Doesn't work for paper 4281
# Doesn't work for paper 4287
# Doesn't work for paper 4288
# Doesn't work for paper 4290
# Doesn't work for paper 4294
# Doesn't work for paper 4310
# Doesn't work for paper 4317
# Doesn't work for paper 4318
# Doesn't work for paper 4320
# Doesn't work for paper 4337
# Doesn't work for paper 4343
# Doesn't work for paper 4346
# Doesn't work for paper 4352
# Doesn't work for paper 4356
# Doesn't work for paper 4360
# Doesn't work for paper 4365
# Doesn't work for paper 4367
# Doesn't work for paper 4381
# Doesn't work for paper 4385
# Doesn't work for paper 4386
# Doesn't work for paper 4387
# Doesn't work for paper 4392
# Doesn't work for paper 4403
# Doesn't work for paper 4407
# Doesn't work for paper 4410
# Doesn't work for paper 4413
# Doesn't work for paper 4417
# Doesn't work for paper 4420
# Doesn't work for paper 4427
# Doesn't work for paper 4432
# Doesn't work for paper 4433
# Doesn't work for paper 4442
# Doesn't work for paper 4444
# Doesn't work for paper 4445
# Doesn't work for paper 4449
# Doesn't work for paper 4451
# Doesn't work for paper 4454
# Doesn't work for paper 4458
# Doesn't work for paper 4465
# Doesn't work for paper 4471
# Doesn't work for paper 4473
# Doesn't work for paper 4479
# Doesn't work for paper 4482
# Doesn't work for paper 4486
# Doesn't work for paper 4488
# Doesn't work for paper 4492
# Doesn't work for paper 4496
# Doesn't work for paper 4504
# Doesn't work for paper 4506
# Doesn't work for paper 4508
# Doesn't work for paper 4510
# Doesn't work for paper 4513
# Doesn't work for paper 4530
# Doesn't work for paper 4545
# Doesn't work for paper 4546
# Doesn't work for paper 4550
# Doesn't work for paper 4569
# Doesn't work for paper 4586
# Doesn't work for paper 4590
# Doesn't work for paper 4594
# Doesn't work for paper 4606
# Doesn't work for paper 4614
# Doesn't work for paper 4618
# Doesn't work for paper 4619
# Doesn't work for paper 4623
# Doesn't work for paper 4624
# Doesn't work for paper 4625
# Doesn't work for paper 4627
# Doesn't work for paper 4630
# Doesn't work for paper 4636
# Doesn't work for paper 4638
# Doesn't work for paper 4642
# Doesn't work for paper 4643
# Doesn't work for paper 4644
# Doesn't work for paper 4647
# Doesn't work for paper 4649
# Doesn't work for paper 4660
# Doesn't work for paper 4661
# Doesn't work for paper 4663
# Doesn't work for paper 4664
# Doesn't work for paper 4672
# Doesn't work for paper 4675
# Doesn't work for paper 4676
# Doesn't work for paper 4683
# Doesn't work for paper 4685
# Doesn't work for paper 4690
# Doesn't work for paper 4691
# Doesn't work for paper 4697
# Doesn't work for paper 4701
# Doesn't work for paper 4704
# Doesn't work for paper 4706
# Doesn't work for paper 4710
# Doesn't work for paper 4718
# Doesn't work for paper 4720
# Doesn't work for paper 4722
# Doesn't work for paper 4729
# Doesn't work for paper 4736
# Doesn't work for paper 4738
# Doesn't work for paper 4739
# Doesn't work for paper 4749
# Doesn't work for paper 4755
# Doesn't work for paper 4757
# Doesn't work for paper 4758
# Doesn't work for paper 4760
# Doesn't work for paper 4767
# Doesn't work for paper 4770
# Doesn't work for paper 4772
# Doesn't work for paper 4776
# Doesn't work for paper 4779
# Doesn't work for paper 4781
# Doesn't work for paper 4783
# Doesn't work for paper 4791
# Doesn't work for paper 4793
# Doesn't work for paper 4795
# Doesn't work for paper 4797
# Doesn't work for paper 4798
# Doesn't work for paper 4800
# Doesn't work for paper 4802
# Doesn't work for paper 4808
# Doesn't work for paper 4809
# Doesn't work for paper 4813
# Doesn't work for paper 4815
# Doesn't work for paper 4816
# Doesn't work for paper 4821
# Doesn't work for paper 4824
# Doesn't work for paper 4830
# Doesn't work for paper 4831
# Doesn't work for paper 4833
# Doesn't work for paper 4840
# Doesn't work for paper 4850
# Doesn't work for paper 4854
# Doesn't work for paper 4855
# Doesn't work for paper 4860
# Doesn't work for paper 4864
# Doesn't work for paper 4865
# Doesn't work for paper 4866
# Doesn't work for paper 4873
# Doesn't work for paper 4878
# Doesn't work for paper 4884
# Doesn't work for paper 4886
# Doesn't work for paper 4888
# Doesn't work for paper 4890
# Doesn't work for paper 4894
# Doesn't work for paper 4898
# Doesn't work for paper 4903
# Doesn't work for paper 4904
# Doesn't work for paper 4908
# Doesn't work for paper 4914
# Doesn't work for paper 4922
# Doesn't work for paper 4923
# Doesn't work for paper 4925
# Doesn't work for paper 4926
# Doesn't work for paper 4927
# Doesn't work for paper 4941
# Doesn't work for paper 4945
# Doesn't work for paper 4954
# Doesn't work for paper 4971
# Doesn't work for paper 4984
# Doesn't work for paper 4986
# Doesn't work for paper 4989
# Doesn't work for paper 4990
# Doesn't work for paper 4992
# Doesn't work for paper 4994
# Doesn't work for paper 4997
# Doesn't work for paper 4999
# Doesn't work for paper 5005
# Doesn't work for paper 5008
# Doesn't work for paper 5009
# Doesn't work for paper 5016
# Doesn't work for paper 5024
# Doesn't work for paper 5031
# Doesn't work for paper 5033
# Doesn't work for paper 5034
# Doesn't work for paper 5036
# Doesn't work for paper 5040
# Doesn't work for paper 5042
# Doesn't work for paper 5044
# Doesn't work for paper 5046
# Doesn't work for paper 5054
# Doesn't work for paper 5066
# Doesn't work for paper 5068
# Doesn't work for paper 5069
# Doesn't work for paper 5070
# Doesn't work for paper 5077
# Doesn't work for paper 5079
# Doesn't work for paper 5082
# Doesn't work for paper 5084
# Doesn't work for paper 5085
# Doesn't work for paper 5086
# Doesn't work for paper 5092
# Doesn't work for paper 5094
# Doesn't work for paper 5095
# Doesn't work for paper 5096
# Doesn't work for paper 5099
# Doesn't work for paper 5102
# Doesn't work for paper 5113
# Doesn't work for paper 5116
# Doesn't work for paper 5118
# Doesn't work for paper 5120
# Doesn't work for paper 5124
# Doesn't work for paper 5128
# Doesn't work for paper 5129
# Doesn't work for paper 5130
# Doesn't work for paper 5135
# Doesn't work for paper 5136
# Doesn't work for paper 5141
# Doesn't work for paper 5142
# Doesn't work for paper 5147
# Doesn't work for paper 5150
# Doesn't work for paper 5152
# Doesn't work for paper 5154
# Doesn't work for paper 5155
# Doesn't work for paper 5156
# Doesn't work for paper 5159
# Doesn't work for paper 5165
# Doesn't work for paper 5169
# Doesn't work for paper 5171
# Doesn't work for paper 5173
# Doesn't work for paper 5175
# Doesn't work for paper 5178
# Doesn't work for paper 5179
# Doesn't work for paper 5182
# Doesn't work for paper 5183
# Doesn't work for paper 5184
# Doesn't work for paper 5190
# Doesn't work for paper 5191
# Doesn't work for paper 5194
# Doesn't work for paper 5195
# Doesn't work for paper 5201
# Doesn't work for paper 5206
# Doesn't work for paper 5212
# Doesn't work for paper 5214
# Doesn't work for paper 5215
# Doesn't work for paper 5216
# Doesn't work for paper 5218
# Doesn't work for paper 5221
# Doesn't work for paper 5228
# Doesn't work for paper 5229
# Doesn't work for paper 5232
# Doesn't work for paper 5236
# Doesn't work for paper 5239
# Doesn't work for paper 5240
# Doesn't work for paper 5244
# Doesn't work for paper 5245
# Doesn't work for paper 5261
# Doesn't work for paper 5267
# Doesn't work for paper 5272
# Doesn't work for paper 5283
# Doesn't work for paper 5302
# Doesn't work for paper 5303
# Doesn't work for paper 5305
# Doesn't work for paper 5307
# Doesn't work for paper 5316
# Doesn't work for paper 5325
# Doesn't work for paper 5332
# Doesn't work for paper 5339
# Doesn't work for paper 5343
# Doesn't work for paper 5349
# Doesn't work for paper 5354
# Doesn't work for paper 5355
# Doesn't work for paper 5369
# Doesn't work for paper 5372
# Doesn't work for paper 5377
# Doesn't work for paper 5380
# Doesn't work for paper 5382
# Doesn't work for paper 5384
# Doesn't work for paper 5387
# Doesn't work for paper 5389
# Doesn't work for paper 5392
# Doesn't work for paper 5399
# Doesn't work for paper 5401
# Doesn't work for paper 5406
# Doesn't work for paper 5412
# Doesn't work for paper 5414
# Doesn't work for paper 5417
# Doesn't work for paper 5419
# Doesn't work for paper 5422
# Doesn't work for paper 5429
# Doesn't work for paper 5430
# Doesn't work for paper 5438
# Doesn't work for paper 5439
# Doesn't work for paper 5443
# Doesn't work for paper 5444
# Doesn't work for paper 5445
# Doesn't work for paper 5451
# Doesn't work for paper 5457
# Doesn't work for paper 5460
# Doesn't work for paper 5461
# Doesn't work for paper 5462
# Doesn't work for paper 5464
# Doesn't work for paper 5466
# Doesn't work for paper 5468
# Doesn't work for paper 5469
# Doesn't work for paper 5471
# Doesn't work for paper 5473
# Doesn't work for paper 5474
# Doesn't work for paper 5481
# Doesn't work for paper 5483
# Doesn't work for paper 5486
# Doesn't work for paper 5487
# Doesn't work for paper 5489
# Doesn't work for paper 5495
# Doesn't work for paper 5497
# Doesn't work for paper 5501
# Doesn't work for paper 5502
# Doesn't work for paper 5506
# Doesn't work for paper 5507
# Doesn't work for paper 5510
# Doesn't work for paper 5512
# Doesn't work for paper 5516
# Doesn't work for paper 5518
# Doesn't work for paper 5519
# Doesn't work for paper 5521
# Doesn't work for paper 5525
# Doesn't work for paper 5529
# Doesn't work for paper 5530
# Doesn't work for paper 5534
# Doesn't work for paper 5535
# Doesn't work for paper 5536
# Doesn't work for paper 5542
# Doesn't work for paper 5543
# Doesn't work for paper 5544
# Doesn't work for paper 5550
# Doesn't work for paper 5551
# Doesn't work for paper 5552
# Doesn't work for paper 5559
# Doesn't work for paper 5564
# Doesn't work for paper 5566
# Doesn't work for paper 5567
# Doesn't work for paper 5568
# Doesn't work for paper 5572
# Doesn't work for paper 5574
# Doesn't work for paper 5578
# Doesn't work for paper 5581
# Doesn't work for paper 5584
# Doesn't work for paper 5586

# %%
main_body = {}
m = 0
for item in body:
    n = int(len(item) / 32767) + 1
    for i in range(0,n):
        if 'text_'+str(i) not in main_body.keys():
            main_body['text_'+str(i)] = ['']*len(data)
        main_body['text_'+str(i)][m] = item[i*32767:min((i+1)*32767,len(item))]
    m += 1

# %%
for key in main_body.keys():
    data[key] = main_body[key]
data['Ack'] = acknow

# %%
data.to_excel('jmd_all_updated.xlsx')

'''
Manual work is needed to check, revise, combine the extracted texts.
'''

# %%
##extract figures from pdf files
##issue: can only run for 20s (~6 papers). Need to split papers into multiple folders woth a smaller number of pdfs

##folder containing pdfs: folder should contain only PDF files
path_in = "folder_with_pdfs"
##folder containing figures
path_out = "figures"
scipdf.parse_figures(path_in, output_folder=path_out)
scipdf.parse_figures(input_folder, output_folder=path)
